# %% [markdown]
# # Universidad Autónoma de Manizales
# ## Procesamiento Digital de Imágenes
# ### Taller filtrado espacial

# %% [markdown]
# **Instrucciones:** Los ejercicios $1$ y $2$ tienen un valor de $+1.5$, y el ejercicio $3$ tienen un valor de $+1.0$.
#
# Los ejercicios pueden ser realizados en parejas.
#
# Se debe subir a través de Google Classroom un archivo (.ipynb) con los nombres de los integrantes.
#
# _Fecha de Entrega:_ 24 de marzo de 2023, 1:59 p.m.

# %% [markdown]
# 1. Cargue una imagen y aplique los dos tipos de ruido vistos en clase. Compare el efecto de los _Box filters_, el filtro gaussiano y el filtro de mediana para la reducción de ruido. Debe mostrar todos los pasos, identificando debidamente las figuras.
#
# **Al final indique cuál de los filtros es más indicado en cada caso.**

# %% [markdown]
# 1. **Respuesta:**
#
#
#
#
#
# ---
#
#
#
# ---

# %% [markdown]
# 2. Implemente los filtros no lineales de máximo y mínimo. Indique en un texto corto sus aplicaciones más relevantes. Se recomienda usar el libro de _Digital Image Processing_ de Gonzalez como referencia.

# %% [markdown]
# 2. **Respuesta:**
#
#
#
#
#
# ---
#
#
#
# ---

# %% [markdown]
# 3. Implemente los operadores Sobel o filtros de realce de primera derivada. Describa su funcionalidad.

# %% [markdown]
# 3. **Respuesta:**
#
#
#
#
#
# ---
#
#
#
# ---
