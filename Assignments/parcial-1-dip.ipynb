# %% [markdown]
# # Universidad Autónoma de Manizales
# ## Procesamiento Digital de Imágenes
# ### Primer Examen parcial - 24 de febrero de 2023

# %% [markdown]
# **Instrucciones:** Las preguntas $1$ a $4$ son de respuesta abierta y tienen un valor de $+0.5$. Las preguntas $5$ a $7$ son ejercicios en los cuales se califica procedimiento y tienen un valor de $+1.0$

# %% [markdown]
# 1. Defina de forma simple y dentro del contexto del procesamiento digital de imágenes ¿qué es una imágen?

# %% [markdown]
# 1. **Respuesta:**
#
#
#
#
#
# ---
#
#
#
# ---

# %% [markdown]
# 2. ¿Cuáles son los pasos a seguir para digitalizar una imagen?

# %% [markdown]
# 2. **Respuesta:**
#
#
#
#
#
# ---
#
#
#
# ---

# %% [markdown]
# 3. Defina de forma simple y dentro del contexto del procesamiento digital de imágenes ¿Cuáles son los vecinos de un píxel? ¿Qué condiciones deben cumplir?

# %% [markdown]
# 3. **Respuesta:**
#
#
#
#
#
# ---
#
#
#
# ---

# %% [markdown]
# 4. ¿Qué representa y/o significa una imagen de 8 bits?

# %% [markdown]
# 4. **Respuesta:**
#
#
#
#
#
# ---
#
#
#
# ---

# %% [markdown]
# 5. A partir de la matriz provista en el archivo de excel (_Matriz10x10.xlsx_) muestre los valores mayores al 70% del máximo y los valores menores al 30% del mínimo.

# %%
# !wget -q https://github.com/MoraRubio/dip-uam/raw/main/src/Matriz10x10.xlsx

# %%
import pandas as pd
import numpy as np

mat = np.array(pd.read_excel('Matriz10x10.xlsx', header=None))

#Inserte su código aquí

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# 6. A partir de la imagen provista (_wrench.png_) y la función de rotar imágenes trabajada en el taller, cree un collage con las siguientes condiciones:
# - El usuario indica si es vertical u horizontal.
# - El usuario indica el número de imágenes (_n_) en el collage (entre 2 - 10).
# - Los grados de rotación de la imagen están dados por el número de imágenes (_n_), es decir, si el usuario indica n=5, las imágenes estarán rotadas en múltiplos de 72° (360°/5).
#
# _Nota:_ Puede usar las funciones cv2.getRotationMatrix2D, cv2.warpAffine y plt.subplots
#
# Ejemplo de salida para collage horizontal con n=6:
#
# <img src='https://github.com/MoraRubio/dip-uam/raw/main/src/output.png'></img>

# %%
# !wget -q https://github.com/MoraRubio/dip-uam/raw/main/src/wrench.png

# %%
#Inserte su código aquí

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# 7. Utilizando la imagen provista (_wrench.png_):
# - Determinar un umbral apropiado para distinguir la primera llave inglesa de las demás.
# - Aplicar la operación de umbralización para generar una máscara binaria con intensidad 1 en los píxeles correspondientes al objeto.
# - Realizar la multiplicación punto a punto de la imagen original con la máscara.
#
# Mostrar la imagen original, el umbral seleccionado, la máscara (resultado de la umbralización) y la imagen final.

# %%
#Inserte su código aquí
