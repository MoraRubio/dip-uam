# %% [markdown]
# # Universidad Autónoma de Manizales
# ## Procesamiento Digital de Imágenes
# ### Taller segmentación de imágenes

# %% [markdown]
# **Instrucciones:** El ejercicio $1$ tiene un valor de $+1.0$, los ejercicios $2$ y $3$ tienen un valor de $+2.0$.
#
# Los ejercicios pueden ser realizados en parejas.
#
# Se debe subir a través de Google Classroom un archivo (.ipynb) con los nombres de los integrantes.
#
# **Fecha de Entrega:** 24 de mayo de 2023, 11:59 p.m.

# %% [markdown]
# 1. Describa de manera general qué información está representada en el dominio de la transformada de _Hough_. Sección 10.2 (Ejemplo 10.11) del libro _Digital Image Processing 4th ed._
# de R. Gonzalez y R. Woods.

# %% [markdown]
# 1. **Respuesta:**
#
#
#
#
#
# ---
#
#
#
# ---

# %% [markdown]
# 2. Reproduzca **uno** de los ejemplos vistos en clase de segmentación de imágenes. Los ejemplos fueron tomados del capítulo 10 del libro de _Digital Image Processing_ de Gonzalez.

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# 3. Siguiendo el [tutorial](https://docs.opencv.org/3.3.1/d3/db4/tutorial_py_watershed.html) de la librería OpenCV, implemente el algoritmo _Watershed_ para segmentación de imágenes. Presente resultados para **dos** imágenes diferentes.

# %% [markdown]
# ---
#
#
#
# ---
